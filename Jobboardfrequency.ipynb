# %%
from bs4 import BeautifulSoup

import urllib
from IPython.display import HTML
import urllib.request
import re

# %%
r = urllib.request.urlopen('https://careers.google.com/jobs/results/?employment_type=INTERN&jlo=en_US&location=United%20States&q=user%20experience').read()
soup = BeautifulSoup(r, "lxml")

# %%
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" itemscope="" itemtype="http://schema.org/WebSite" lang="en">
#  <head>
#   <link crossorigin="" href="https://www.googletagmanager.com" rel="preconnect"/>
#   <link crossorigin="" href="https://www.googleoptimize.com" rel="preconnect"/>
#   <style>
#    .async-hide { opacity: 0 !important}
#   </style>
#   <script nonce="MP/IStxpUzzFNeOJxanZAQ==">
#    (function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
#         h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
#         (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
#         })(window,document.documentElement,'async-hide','dataLayer',4000,
#         {'GTM-NS57G2W':true});
#   </script>
#   <!-- Google Tag Manager -->
#   <script nonce="MP/IStxpUzzFNeOJxanZAQ==">
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# ...
